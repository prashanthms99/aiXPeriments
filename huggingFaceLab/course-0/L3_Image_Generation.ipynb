# %%
import os
import io
import IPython.display
from PIL import Image
import base64 
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file
hf_api_key = os.environ['HF_API_KEY']

# %%
# Helper function
import requests, json

#Text-to-image endpoint
def get_completion(inputs, parameters=None, ENDPOINT_URL=os.environ['HF_API_TTI_BASE']):
    headers = {
      "Authorization": f"Bearer {hf_api_key}",
      "Content-Type": "application/json"
    }   
    data = { "inputs": inputs }
    if parameters is not None:
        data.update({"parameters": parameters})
    response = requests.request("POST",
                                ENDPOINT_URL,
                                headers=headers,
                                data=json.dumps(data))
    print(response.content)
    return json.loads(response.content.decode("utf-8"))

# %%
import gradio as gr 

#A helper function to convert the PIL image to base64
#so you can send it to the API
def base64_to_pil(img_base64):
    base64_decoded = base64.b64decode(img_base64)
    byte_stream = io.BytesIO(base64_decoded)
    pil_image = Image.open(byte_stream)
    return pil_image

def generate(prompt):
    output = get_completion(prompt)
    result_image = base64_to_pil(output)
    return result_image

gr.close_all()
demo = gr.Interface(fn=generate,
                    inputs=[gr.Textbox(label="Your prompt")],
                    outputs=[gr.Image(label="Result")],
                    title="Image Generation with Stable Diffusion",
                    description="Generate any image with Stable Diffusion",
                    allow_flagging="never",
                    examples=["the spirit of a tamagotchi wandering in the city of Vienna","a mecha robot in a favela"])

demo.launch(share=True, server_port=int(os.environ['PORT1']))
# Out:
# Closing server running on port: 8080
# Closing server running on port: 8080
# Running on local URL:  http://127.0.0.1:8080
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:8080/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x02\x00\x02\x00\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00g\x894f\x8e\xf6xB\x90T\x92=\rq\xc62\xad\xb4\xf0GQ^\xe9\xe2\x9d\x14_!\x962RE\xe7 u\xaf*\xf1.\x9a,\xa7\x89\x80\xc1q\xf3}k\xd0\xc3\xd4\xbe\x87%H\xd9\x98 S\xc7Z1K\xb7\xa5u\x98\x8eS\x83S\x03\xc6*%\x15"\xd0"D}\xac\x08\xed\xda\xb4\xacu\x19-\xee\x15\xf2q\x9e\x95\x98\x0752\xf6\xa4\xd5\xc0\xd8\xd5\xde\x1b\x92\xb7\x11|\xae\xdfxV_ \x80x\xa7\xa1\xe3\xd6\xa4*\x1b\x9e\xf4%d\x03\xa1\x95\xd7\x15\xa5opx\x0c>\xb5f\xca\xc2\x03\x04{\xc09\xee*\xe4\x9a|*G\x1c\xfbVnHi\x05\xbe\xd9\x8f\x04\x8a\xbd4Jm\xc8#\r\xda\xa9%\xbf\x92\xfb\x83q\xe9S\xbc\xa5\x80\x0cx\xf4\xa8(\xce#\x0f\xd7\xbdn\xf8i\xff\x00\xe2h\xbd\x86\xd3\xcdc\xcb\x1e[8\xad\xef\x0f\xe9W2\xc6\xf7#\x85\xc6\x10\xfa\xd2\xa9nP\x82|\xc7Y(K\xa8\x99H\xcf\xb5P}\x1c<l\xaa6\x95\xe4\x10(\xb7i\xe2o-\xc1\x04\x1e\xa7\xbdlD\xdf\xbb\x1e\xfdk\x92\xee\'U\xaes\xb6\xf9\x8f) \xe4u\xab\xb6\x80;\x82O\x19\xe9ZO\x04J\xa4\x94\xc6\xea\xa5",M\xb9\x0f\xe1E\xee\x16\xb1\xa1\xe4\x03\xf3/\xe5Ks\x08\xd9\x90~oz\xafkq\xc0\xc9\xabN\xca\xf1\xe39\xcdF\xa5\x0c\xb7\x94\x9c\x0fN\xb5v93\xc5PY#\x8d\xb0\x0f5f\'\xf9\xb8\xa1\xa0C\xe69$V\\\xed\x82O\xa5]\xbb\x9b\xcb\x04\xd6T\xad\xbfp\xc8\xe9\x9eM\x08L\xc1\xf1o\x89\xe0\xf0\xc7\x87\xae5\x19\x082\x01\xb6\x18\xc9\xe5\xdc\xf4\x15\xf3\x85\x94Muq&\xa3q\xf3\xc9+\xb3d\xfa\x93\xc9\xad\xbf\x1b\xeb\x92\xf8\xb7\xc5\xf3\x88\xa6s\xa6Z7\x97\x12\x13\xc0\x03\xab}I\xaa\xc1\x02\xfc\xaa0\xa3\xa0\xf4\xacjO\xa0\xa5/f\xbc\xc6\x11I\x8e*LRb\xb19[\xb9\x11Z\xadp\xfe\\g\x1f{\xa0\x15f\xe1\xfc\x98Y\xc0\xc9\x03\x81T\xdb2\xa29\x1c\x91\xc8\xa6\x91p\x8fR\x15\x95O^\rH9\xa8\xfc\xac\x9c\xe2\x9aca\xd3?ATkdX\x04S\x86\x08\xaa\xf9u^\xb9\xf6\xa3\xce#\xef/\xe5H9K`\x803\xde\xa8\xea\x17AbdS\xcfCJ\xd2\xe4\x1c\x1cVu\xc1\xcf\x19\xe9\xd6\xa9!\xc2\x1a\xeav\xfe\x0c]\xda|c\xd9\x8f\xeb[\x93\'&\xb1<\x10\xc5\xacb\\\xf6p?:\xe9%L\xb1\x15\xba\xd8\xb7\xb9\x9a\xd1\xe4TM\x17<U\xf6Oj\x8fn9\xa6\x05C\x1e\x075\x1e\xcc\xf4\xabn\xbb\x81\x15\x1f\x97\xb7\x81\xd2\x80+\x94\xc1\xa6\x15\xabf/\x98\x1e\xd4\x8d\x10s\xc0\xa6\x055B\xc7\xd2\xad\xc5\x01\xf2\xc9\xc5]\xb4\xb12\xc8\x8a\x17$\x9cWSy\xe1\x99a\xfb4(\x87yL\xbe\x051\x9c\xf6\x8f\xa7\xc9u\x7f\x05\xb0\xc0\xdcz\xd7{a\xe1\xeb\xa5\xd4\xc4p& \x8b\x19l\xf5\x15CD\xd2\x1e\xd5\xdaWR\x19s\xb5\xab\xd0\xf4\x9cA\xa7\xa2\xb1\xdc\xc4d\x ...
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\envs\keras\lib\site-packages\gradio\routes.py", line 442, in run_predict
#     output = await app.get_blocks().process_api(
#   File "C:\ProgramData\anaconda3\envs\keras\lib\site-packages\gradio\blocks.py", line 1392, in process_api
#     result = await self.call_function(
#   File "C:\ProgramData\anaconda3\envs\keras\lib\site-packages\gradio\blocks.py", line 1097, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "C:\ProgramData\anaconda3\envs\keras\lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(func, *args, cancellable=cancellable,
#   File "C:\ProgramData\anaconda3\envs\keras\lib\site-packages\anyio\_backends\_asyncio.py", line 818, in run_sync_in_worker_thread
#     return await future
#   File "C:\ProgramData\anaconda3\envs\keras\lib\site-packages\anyio\_backends\_asyncio.py", line 754, in run
#     result = context.run(func, *args)
#   File "C:\ProgramData\anaconda3\envs\keras\lib\site-packages\gradio\utils.py", line 703, in wrapper
#     response = f(*args, **kwargs)
#   File "C:\Users\prashanth\AppData\Local\Temp\ipykernel_27756\1068206421.py", line 12, in generate
#     output = get_completion(prompt)
#   File "C:\Users\prashanth\AppData\Local\Temp\ipykernel_27756\3693353998.py", line 18, in get_completion
#     return json.loads(response.content.decode("utf-8"))
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
